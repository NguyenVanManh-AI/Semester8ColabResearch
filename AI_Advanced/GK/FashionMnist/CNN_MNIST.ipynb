# %% [markdown]
# ## Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPooling2D
from IPython.display import SVG
# from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly import tools
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Init

# %%
IMG_ROWS = 28
IMG_COLS = 28
NUM_CLASSES = 10
TEST_SIZE = 0.2
RANDOM_STATE = 42
#Model
NO_EPOCHS = 50
BATCH_SIZE = 128

# %%
import os
os.chdir("/content/drive/MyDrive/5_AIADVANCE/FashionMnist")
os.getcwd()
# Out:
# '/content/drive/.shortcut-targets-by-id/1WYkIM110xY1VpfnGHkdvas_3vSRNFR6S/5_AIADVANCE/FashionMnist'

# %% [markdown]
# ## Load Data

# %%
train_file = "./Data/fashion-mnist_train.csv"
train_data = pd.read_csv(train_file)

# %% [markdown]
# ## Processing

# %%
# Create a dictionary for each type of label
labels = {0 : "T-shirt/top", 1: "Trouser", 2: "Pullover", 3: "Dress", 4: "Coat",
          5: "Sandal", 6: "Shirt", 7: "Sneaker", 8: "Bag", 9: "Ankle Boot"}

def get_classes_distribution(data):
    # Get the count for each label
    label_counts = data["label"].value_counts()

    # Get total number of samples
    total_samples = len(data)


    # Count the number of items in each class
    for i in range(len(label_counts)):
        label = labels[label_counts.index[i]]
        count = label_counts.values[i]
        percent = (count / total_samples) * 100
        print("{:<20s}:   {} or {}%".format(label, count, percent))

get_classes_distribution(train_data)
# Out:
# Pullover            :   6000 or 10.0%
# Ankle Boot          :   6000 or 10.0%
# Shirt               :   6000 or 10.0%
# T-shirt/top         :   6000 or 10.0%
# Dress               :   6000 or 10.0%
# Coat                :   6000 or 10.0%
# Sandal              :   6000 or 10.0%
# Bag                 :   6000 or 10.0%
# Sneaker             :   6000 or 10.0%
# Trouser             :   6000 or 10.0%

# %%
# data preprocessing
def data_preprocessing(raw):
    out_y = keras.utils.to_categorical(raw.label, NUM_CLASSES)
    num_images = raw.shape[0]
    x_as_array = raw.values[:,1:]
    x_shaped_array = x_as_array.reshape(num_images, IMG_ROWS, IMG_COLS, 1)
    out_x = x_shaped_array / 255
    return out_x, out_y

# %%
# prepare the data
X, y = data_preprocessing(train_data)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

# %%
print("Fashion MNIST train -  rows:",X_train.shape[0]," columns:", X_train.shape[1:4])
print("Fashion MNIST valid -  rows:",X_val.shape[0]," columns:", X_val.shape[1:4])
# Out:
# Fashion MNIST train -  rows: 48000  columns: (28, 28, 1)
# Fashion MNIST valid -  rows: 12000  columns: (28, 28, 1)

# %% [markdown]
# ## Model

# %%
# Model
model = Sequential()
# Add convolution 2D
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(IMG_ROWS, IMG_COLS, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64,
                 kernel_size=(3, 3),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(NUM_CLASSES, activation='softmax'))

# %%
from keras.optimizers import Adam

# Khởi tạo trình tối ưu Adam với tốc độ học 0.0002 (ví dụ)
optimizer = Adam(learning_rate=0.0002)
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_4 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten_2 (Flatten)         (None, 1152)              0
#
#  dense_4 (Dense)             (None, 128)               147584
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 241546 (943.54 KB)
# Trainable params: 241546 (943.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
history = model.fit(
    X_train,
    y_train,
    batch_size=BATCH_SIZE,
    epochs=NO_EPOCHS,
    verbose=1,
    validation_data=(X_val,y_val),
)
# Out:
# Epoch 1/50
# 375/375 [==============================] - 4s 6ms/step - loss: 0.8547 - accuracy: 0.7054 - val_loss: 0.5695 - val_accuracy: 0.7887
# Epoch 2/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.5132 - accuracy: 0.8100 - val_loss: 0.4573 - val_accuracy: 0.8346
# Epoch 3/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4475 - accuracy: 0.8382 - val_loss: 0.4260 - val_accuracy: 0.8419
# Epoch 4/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4075 - accuracy: 0.8536 - val_loss: 0.3857 - val_accuracy: 0.8567
# Epoch 5/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.3823 - accuracy: 0.8612 - val_loss: 0.3724 - val_accuracy: 0.8635
# Epoch 6/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3585 - accuracy: 0.8706 - val_loss: 0.3489 - val_accuracy: 0.8723
# Epoch 7/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3398 - accuracy: 0.8777 - val_loss: 0.3336 - val_accuracy: 0.8769
# Epoch 8/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3213 - accuracy: 0.8850 - val_loss: 0.3261 - val_accuracy: 0.8823
# Epoch 9/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3098 - accuracy: 0.8881 - val_loss: 0.3149 - val_accuracy: 0.8848
# Epoch 10/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2974 - accuracy: 0.8930 - val_loss: 0.3018 - val_accuracy: 0.8929
# Epoch 11/50
# 375/375 [==============================] - 2s 7ms/step - loss: 0.2885 - accuracy: 0.8964 - val_loss: 0.2977 - val_accuracy: 0.8941
# Epoch 12/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2782 - accuracy: 0.8985 - val_loss: 0.2999 - val_accuracy: 0.8917
# Epoch 13/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2699 - accuracy: 0.9026 - val_loss: 0.2902 - val_accuracy: 0.8933
# Epoch 14/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2620 - accuracy: 0.9053 - val_loss: 0.2917 - val_accuracy: 0.8960
# Epoch 15/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2563 - accuracy: 0.9076 - val_loss: 0.2836 - val_accuracy: 0.8972
# Epoch 16/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2468 - accuracy: 0.9111 - val_loss: 0.2802 - val_accuracy: 0.8988
# Epoch 17/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2405 - accuracy: 0.9125 - val_loss: 0.2731 - val_accuracy: 0.8997
# Epoch 18/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2365 - accuracy: 0.9139 - val_loss: 0.2645 - val_accuracy: 0.9007
# Epoch 19/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2282 - accuracy: 0.9169 - val_loss: 0.2708 - val_accuracy: 0.9010
# Epoch 20/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2213 - accuracy: 0.9195 - val_loss: 0.2630 - val_accuracy: 0.9051
# Epoch 21/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2163 - accuracy: 0.9216 - val_loss: 0.2595 - val_accuracy: 0.9075
# Epoch 22/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2102 - accuracy: 0.9248 - val_loss: 0.2599 - val_accuracy: 0.9057
# Epoch 23/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2059 - accuracy: 0.9254 - val_loss: 0.2628 - val_accuracy: 0.9063
# Epoch 24/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1994 - accuracy: 0.9280 - val_loss: 0.2601 - val_accuracy: 0.9040
# Epoch 25/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1962 - accuracy: 0.9279 - val_loss: 0.2561 - val_accuracy: 0.9080
# Epoch 26/50
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1894 - accuracy: 0.9314 - val_loss: 0.2498 - val_accuracy: 0.9068
# Epoch 27/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1847 - accuracy: 0.9333 - val_loss: 0.2534 - val_accuracy: 0.9088
# Epoch 28/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1799 - accuracy: 0.9350 - val_loss: 0.2583 - val_accuracy: 0.9061
# Epoch 29/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1756 - accuracy: 0.9360 - val_loss: 0.2551 - val_accuracy: 0.9072
# Epoch 30/50
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1696 - accuracy: 0.9375 - val_loss: 0.2611 - val_accuracy: 0.9079
# Epoch 31/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1650 - accuracy: 0.9394 - val_loss: 0.2599 - val_accuracy: 0.9087
# Epoch 32/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1609 - accuracy: 0.9420 - val_loss: 0.2569 - val_accuracy: 0.9096
# Epoch 33/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1563 - accuracy: 0.9435 - val_loss: 0.2550 - val_accuracy: 0.9110
# Epoch 34/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1528 - accuracy: 0.9446 - val_loss: 0.2624 - val_accuracy: 0.9092
# Epoch 35/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1481 - accuracy: 0.9461 - val_loss: 0.2779 - val_accuracy: 0.9047
# Epoch 36/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1436 - accuracy: 0.9477 - val_loss: 0.2645 - val_accuracy: 0.9099
# Epoch 37/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1406 - accuracy: 0.9490 - val_loss: 0.2553 - val_accuracy: 0.9109
# Epoch 38/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1345 - accuracy: 0.9525 - val_loss: 0.2587 - val_accuracy: 0.9097
# Epoch 39/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1303 - accuracy: 0.9535 - val_loss: 0.2579 - val_accuracy: 0.9129
# Epoch 40/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1283 - accuracy: 0.9538 - val_loss: 0.2627 - val_accuracy: 0.9095
# Epoch 41/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1262 - accuracy: 0.9538 - val_loss: 0.2696 - val_accuracy: 0.9131
# Epoch 42/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1190 - accuracy: 0.9573 - val_loss: 0.2757 - val_accuracy: 0.9108
# Epoch 43/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1165 - accuracy: 0.9577 - val_loss: 0.2751 - val_accuracy: 0.9112
# Epoch 44/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1113 - accuracy: 0.9608 - val_loss: 0.2658 - val_accuracy: 0.9128
# Epoch 45/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1097 - accuracy: 0.9608 - val_loss: 0.2782 - val_accuracy: 0.9092
# Epoch 46/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1056 - accuracy: 0.9621 - val_loss: 0.2782 - val_accuracy: 0.9111
# Epoch 47/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1017 - accuracy: 0.9637 - val_loss: 0.2790 - val_accuracy: 0.9124
# Epoch 48/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0985 - accuracy: 0.9646 - val_loss: 0.2787 - val_accuracy: 0.9130
# Epoch 49/50
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0957 - accuracy: 0.9656 - val_loss: 0.2773 - val_accuracy: 0.9146
# Epoch 50/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0911 - accuracy: 0.9680 - val_loss: 0.2939 - val_accuracy: 0.9129

# %% [markdown]
# ## Evaluate

# %%
score = model.evaluate(X_val,y_val,verbose=0)
print('val Loss : {:.4f}'.format(score[0]))
print('val Accuracy : {:.4f}'.format(score[1]))
# Out:
# val Loss : 0.2939
# val Accuracy : 0.9129

# %%
plt.figure(figsize=(10, 10))

plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Training - Loss Function')

plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Train - Accuracy')
# Out:
# Text(0.5, 1.0, 'Train - Accuracy')

# %%
from sklearn.metrics import classification_report

# Dự đoán nhãn cho dữ liệu validation
y_pred = model.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)

# Chuyển đổi one-hot encoded labels thành nhãn dạng scalar
y_true_classes = np.argmax(y_val, axis=1)

# Tính và hiển thị báo cáo phân loại
print(classification_report(y_true_classes, y_pred_classes))
# Out:
# 375/375 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87      1232
#            1       1.00      0.97      0.98      1174
#            2       0.87      0.85      0.86      1200
#            3       0.89      0.94      0.92      1242
#            4       0.87      0.86      0.87      1185
#            5       0.97      0.99      0.98      1141
#            6       0.76      0.75      0.75      1243
#            7       0.96      0.96      0.96      1224
#            8       0.96      0.99      0.98      1149
#            9       0.98      0.96      0.97      1210
#
#     accuracy                           0.91     12000
#    macro avg       0.91      0.91      0.91     12000
# weighted avg       0.91      0.91      0.91     12000
